# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose **Lane 2: Refresh / Content Opportunity Scoring** because I want to identify which pages should be reviewed first. This lane uses search and engagement data to help prioritize pages that may need improvement.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Question:** Which pages should be reviewed first?
#
# **Decision:** Choose the pages to review first.
#
# **Action:** The content team reviews and updates those pages.
#
# **Cost:** If the recommendation is wrong, the team may waste time on the wrong pages and miss better opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Number of rows: 30000
# Average impressions (90d): 5200.37
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project is a decision-support tool. It can identify observed patterns in search and engagement data and help prioritize which pages should be reviewed first. The results are directional and based on measured signals in the dataset.
#
# This project cannot prove that refreshing a page will improve its performance, cannot predict Google's algorithms, and cannot establish causal relationships between content changes and future results.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
